# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT281/blob/main/docs/labs/lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # MAT281 - Laboratorio N°03

# %% [markdown]
# **Objetivo**: Aplicar técnicas avanzadas de manipulación y análisis de datos con pandas sobre un conjunto real de datos de contenido de Netflix, reforzando buenas prácticas y métodos eficientes sin recurrir a `groupby`, `merge`, `pivot`, ni `join`.
#
#
#
# **Dataset**:
#
# Trabajaremos con el archivo `netflix_titles.csv`, que contiene información sobre los títulos disponibles en la plataforma Netflix hasta el año 2021.
#
# | Variable       | Clase     | Descripción                                                                 |
# |----------------|-----------|------------------------------------------------------------------------------|
# | show_id        | caracter  | Identificador único del título en el catálogo de Netflix.                   |
# | type           | caracter  | Tipo de contenido: 'Movie' o 'TV Show'.                                     |
# | title          | caracter  | Título del contenido.                                                       |
# | director       | caracter  | Nombre del director (puede ser nulo).                                       |
# | cast           | caracter  | Lista de actores principales (puede ser nulo).                              |
# | country        | caracter  | País o países donde se produjo el contenido.                                |
# | date_added     | fecha     | Fecha en la que el título fue agregado al catálogo de Netflix.              |
# | release_year   | entero    | Año de lanzamiento original del título.                                     |
# | rating         | caracter  | Clasificación por edad (por ejemplo: 'PG-13', 'TV-MA').                      |
# | duration       | caracter  | Duración del contenido (minutos o número de temporadas para series).        |
# | listed_in      | caracter  | Categorías o géneros en los que está clasificado el contenido.              |
# | description    | caracter  | Breve sinopsis del contenido.                                               |

# %%
import pandas as pd

# Cargar datos
df = pd.read_csv('https://raw.githubusercontent.com/fralfaro/MAT281/main/docs/labs/data/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Parte 1: Limpieza y preparación
#
# 1. Revisar y describir el dataset:
#
#    * ¿Cuántas filas y columnas tiene?
#    * ¿Qué tipos de datos hay?
#    * ¿Cuántos valores nulos hay por columna?
#
# 2. Transformar la columna `date_added` a tipo fecha.
#
# 3. Crear columnas auxiliares con `assign`:
#
#    * Año (`year_added`)
#    * Mes (`month_added`)

# %%
df.info()
df.dtypes
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 1. Por la información dada arriba, se ve que hay 8807 filas y 12 columnas, además los tipos de datos son object e int, y por último las columnas que si tienen valores son las siguientes (la tabla de arriba básicamebte): director 2634; cast 825; country 931; date_added 10; rating 4; duration 3.

# %%
import datetime
df['new_date'] = pd.to_datetime(df['date_added'].str.strip(), errors='coerce')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description   new_date
# 0  As her father nears the end of his life, filmm... 2021-09-25
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24
# 2  To protect his family from a powerful drug lor... 2021-09-24
# 3  Feuds, flirtations and toilet talk go down amo... 2021-09-24
# 4  In a city of coaching centers known to train I... 2021-09-24

# %%
df = df.assign(
    year_added  = df['new_date'].dt.year.astype('Int64'),
    month_added = df['new_date'].dt.month.astype('Int64')
)
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description   new_date  year_added  \
# 0  As her father nears the end of his life, filmm... 2021-09-25        2021
# 1  After crossing paths at a party, a Cape Town t... 2021-09-24        2021
# 2  To protect his family from a powerful drug lor... 2021-09-24        2021
# 3  Feuds, flirtations and toilet talk go down amo... 2021-09-24        2021
# 4  In a city of coaching centers known to train I... 2021-09-24        2021
#
#    month_added
# 0            9
# 1            9
# 2            9
# 3            9
# 4            9

# %% [markdown]
# ## Parte 2: Técnicas avanzadas de pandas
#
# 4. Utilizar `.loc` para seleccionar películas (`type == 'Movie'`) que fueron agregadas después del año 2018.
#
# 5. Utilizar `str.contains()` y `str.extract()`:
#
#    * Filtrar títulos que contienen la palabra 'love' (sin distinguir mayúsculas/minúsculas).
#    * Extraer la duración en minutos para las películas desde la columna `duration`.
#
# 6. Aplicar `explode()` sobre la columna `listed_in` para obtener una fila por cada género.
#
# 7. Obtener un top 10 de géneros más frecuentes utilizando `value_counts()`.
#
# 8. Aplicar `where()` y `mask()` para marcar las películas de más de 120 minutos como contenido largo en una nueva columna.
#
# 9. Utilizar `.loc` para filtrar películas que cumplen con:
#
#    * Más de 100 minutos de duración.
#    * Rating igual a `'R'`.
#    * País igual a `'United States'`.
#
# 10. Utilizar `.style` para formatear visualmente el top 10 de películas más largas.

# %%
df_4 = df.loc[(df['year_added'] == 2018) & (df['type'] == "Movie")]
df_4.head()
# Out:
#      show_id   type                        title                     director  \
# 4229   s4230  Movie  Bill Hicks: One Night Stand             John Fortenberry
# 4230   s4231  Movie      Bill Hicks: Reflections                          NaN
# 4231   s4232  Movie       Bill Hicks: Relentless                  Chris Bould
# 4232   s4233  Movie      Bill Hicks: Revelations                  Chris Bould
# 4233   s4234  Movie         Bill Hicks: Sane Man  Kevin Booth, David Johndrow
#
#                          cast         country         date_added  \
# 4229               Bill Hicks  United Kingdom  December 31, 2018
# 4230  Bill Hicks, Steve Hicks             NaN  December 31, 2018
# 4231               Bill Hicks  United Kingdom  December 31, 2018
# 4232               Bill Hicks  United Kingdom  December 31, 2018
# 4233               Bill Hicks   United States  December 31, 2018
#
#       release_year rating duration        listed_in  \
# 4229          1991  TV-MA   28 min  Stand-Up Comedy
# 4230          2015  TV-MA   34 min    Documentaries
# 4231          1992  TV-MA   61 min  Stand-Up Comedy
# 4232          1993  TV-MA   56 min  Stand-Up Comedy
# 4233          1989  TV-MA   81 min  Stand-Up Comedy
#
#                                             description   new_date  \
# 4229  Bill Hicks remembers a wild night in 1989 and ... 2018-12-31
# 4230  This documentary about comedian Bill Hicks off... 2018-12-31
# 4231  In one of his most iconic performances, late c... 2018-12-31
# 4232  In his final recorded special, the iconoclasti... 2018-12-31
# 4233  Filmed in 1989 at a turning point in comedian ... 2018-12-31
#
#       year_added  month_added
# 4229        2018           12
# 4230        2018           12
# 4231        2018           12
# 4232        2018           12
# 4233        2018           12

# %%
df_5a = df.loc[df['title'].str.contains("love", case=False, na=False)]
df_5a.head()
# Out:
#     show_id     type                      title               director  \
# 25      s26  TV Show       Love on the Spectrum                    NaN
# 158    s159    Movie    Love Don't Cost a Thing              Troy Byer
# 159    s160    Movie             Love in a Puff         Pang Ho-cheung
# 206    s207    Movie  LSD: Love, Sex Aur Dhokha       Dibakar Banerjee
# 227    s228    Movie                Really Love  Angel Kristi Williams
#
#                                                   cast        country  \
# 25                                    Brooke Satchwell      Australia
# 158  Nick Cannon, Christina Milian, Kenan Thompson,...  United States
# 159  Miriam Chin Wah Yeung, Shawn Yue, Singh Hartih...      Hong Kong
# 206  Nushrat Bharucha, Anshuman Jha, Neha Chauhan, ...          India
# 227  Kofi Siriboe, Yootha Wong-Loi-Sing, Michael Ea...  United States
#
#              date_added  release_year rating   duration  \
# 25   September 21, 2021          2021  TV-14  2 Seasons
# 158   September 1, 2021          2003  PG-13    101 min
# 159   September 1, 2021          2010  TV-MA    103 min
# 206     August 27, 2021          2010  TV-MA    112 min
# 227     August 25, 2021          2020  TV-MA     95 min
#
#                                             listed_in  \
# 25     Docuseries, International TV Shows, Reality TV
# 158                         Comedies, Romantic Movies
# 159            Comedies, Dramas, International Movies
# 206  Dramas, Independent Movies, International Movies
# 227       Dramas, Independent Movies, Romantic Movies
#
#                                            description   new_date  year_added  \
# 25   Finding love can be hard for anyone. For young... 2021-09-21        2021
# 158  A nerdy teen tries to make himself cool by ass... 2021-09-01        2021
# 159  When the Hong Kong government enacts a ban on ... 2021-09-01        2021
# 206  This provocative drama examines how the voyeur... 2021-08-27        2021
# 227  A rising Black painter tries to break into a c... 2021-08-25        2021
#
#      month_added
# 25             9
# 158            9
# 159            9
# 206            8
# 227            8

# %%
df_5b = df.loc[df['type'] == "Movie"].copy()
df_5b = df_5b.assign(duration_minutes = df_5b['duration'].str.extract(r'(\d+)').astype('Int64'))
df_5b[['title','duration','duration_minutes']].head()
# Out:
#                                title duration  duration_minutes
# 0               Dick Johnson Is Dead   90 min                90
# 6   My Little Pony: A New Generation   91 min                91
# 7                            Sankofa  125 min               125
# 9                       The Starling  104 min               104
# 12                      Je Suis Karl  127 min               127

# %%
df_6 = df.assign(
    listed_in = df['listed_in'].str.split(r',\s*')
).explode('listed_in')

df_6[['title', 'listed_in']].head()
# Out:
#                   title               listed_in
# 0  Dick Johnson Is Dead           Documentaries
# 1         Blood & Water  International TV Shows
# 1         Blood & Water               TV Dramas
# 1         Blood & Water            TV Mysteries
# 2             Ganglands          Crime TV Shows

# %%
df_7 = df.assign(
    listed_in = df['listed_in'].str.split(r',\s*')
).explode('listed_in')
df_7 = df_exploded['listed_in'].value_counts().head(10)
print(top_10_genres)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1351
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    763
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
df['duration_minutes'] = df['duration'].str.extract(r'(\d+)').astype('Int64')
df['length_category'] = df['duration_minutes'].astype('object')
df['length_category'] = df['length_category'].mask(df['duration_minutes'] > 120, 'Contenido largo')
df[['title', 'duration', 'duration_minutes', 'length_category']].head()
# Out:
#                    title   duration  duration_minutes length_category
# 0   Dick Johnson Is Dead     90 min                90              90
# 1          Blood & Water  2 Seasons                 2               2
# 2              Ganglands   1 Season                 1               1
# 3  Jailbirds New Orleans   1 Season                 1               1
# 4           Kota Factory  2 Seasons                 2               2

# %%
df_9 = df.loc[
    (df['duration_minutes'] > 100) &
    (df['rating'] == 'R') &
    (df['country'] == 'United States')
]

df_9.head()
# Out:
#     show_id   type                        title               director  \
# 48      s49  Movie                 Training Day          Antoine Fuqua
# 81      s82  Movie                         Kate  Cedric Nicolas-Troyan
# 131    s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# 139    s140  Movie           Do the Right Thing              Spike Lee
# 144    s145  Movie                  House Party        Reginald Hudlin
#
#                                                   cast        country  \
# 48   Denzel Washington, Ethan Hawke, Scott Glenn, T...  United States
# 81   Mary Elizabeth Winstead, Jun Kunimura, Woody H...  United States
# 131  Harrison Ford, Rutger Hauer, Sean Young, Edwar...  United States
# 139  Danny Aiello, Ossie Davis, Ruby Dee, Richard E...  United States
# 144  Christopher Reid, Christopher Martin, Robin Ha...  United States
#
#              date_added  release_year rating duration  \
# 48   September 16, 2021          2001      R  122 min
# 81   September 10, 2021          2021      R  106 min
# 131   September 1, 2021          1982      R  117 min
# 139   September 1, 2021          1989      R  120 min
# 144   September 1, 2021          1990      R  104 min
#
#                                            listed_in  \
# 48                                 Dramas, Thrillers
# 81                                Action & Adventure
# 131  Action & Adventure, Classic Movies, Cult Movies
# 139                 Classic Movies, Comedies, Dramas
# 144                            Comedies, Cult Movies
#
#                                            description   new_date  year_added  \
# 48   A rookie cop with one day to prove himself to ... 2021-09-16        2021
# 81   Slipped a fatal poison on her final job, a rut... 2021-09-10        2021
# 131  In a smog-choked dystopian Los Angeles, blade ... 2021-09-01        2021
# 139  On a sweltering day in Brooklyn, simmering rac... 2021-09-01        2021
# 144  Grounded by his strict father, Kid risks life ... 2021-09-01        2021
#
#      month_added  duration_minutes  length_category
# 48             9               122  Contenido largo
# 81             9               106              106
# 131            9               117              117
# 139            9               120              120
# 144            9               104              104

# %%
df_10 = df.loc[df['type'] == 'Movie'].nlargest(10, 'duration_minutes')

# Formatear solo la columna de duración
df_10.style.format({'duration_minutes': '{:.0f} min'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_5102e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5102e_level0_col0" class="col_heading level0 col0" >show_id</th>
#       <th id="T_5102e_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_5102e_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_5102e_level0_col3" class="col_heading level0 col3" >director</th>
#       <th id="T_5102e_level0_col4" class="col_heading level0 col4" >cast</th>
#       <th id="T_5102e_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_5102e_level0_col6" class="col_heading level0 col6" >date_added</th>
#       <th id="T_5102e_level0_col7" class="col_heading level0 col7" >release_year</th>
#       <th id="T_5102e_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_5102e_level0_col9" class="col_heading level0 col9" >duration</th>
#       <th id="T_5102e_level0_col10" class="col_heading level0 col10" >listed_in</th>
#       <th id="T_5102e_level0_col11" class="col_heading level0 col11" >description</th>
#       <th id="T_5102e_level0_col12" class="col_heading level0 col12" >new_date</th>
#       <th id="T_5102e_level0_col13" class="col_heading level0 col13" >year_added</th>
#       <th id="T_5102e_level0_col14" class="col_heading level0 col14" >month_added</th>
#       <th id="T_5102e_level0_col15" class="col_heading level0 col15" >duration_minutes</th>
#       <th id="T_5102e_level0_col16" class="col_heading level0 col16" >length_category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5102e_level0_row0" class="row_heading level0 row0" >4253</th>
#       <td id="T_5102e_row0_col0" class="data row0 col0" >s4254</td>
#       <td id="T_5102e_row0_col1" class="data row0 col1" >Movie</td>
#       <td id="T_5102e_row0_col2" class="data row0 col2" >Black Mirror: Bandersnatch</td>
#       <td id="T_5102e_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_5102e_row0_col4" class="data row0 col4" >Fionn Whitehead, Will Poulter, Craig Parkinson, Alice Lowe, Asim Chaudhry</td>
#       <td id="T_5102e_row0_col5" class="data row0 col5" >United States</td>
#       <td id="T_5102e_row0_col6" class="data row0 col6" >December 28, 2018</td>
#       <td id="T_5102e_row0_col7" class="data row0 col7" >2018</td>
#       <td id="T_5102e_row0_col8" class="data row0 col8" >TV-MA</td>
#       <td id="T_5102e_row0_col9" class="data row0 col9" >312 min</td>
#       <td id="T_5102e_row0_col10" class="data row0 col10" >Dramas, International Movies, Sci-Fi & Fantasy</td>
#       <td id="T_5102e_row0_col11" class="data row0 col11" >In 1984, a young programmer begins to question reality as he adapts a dark fantasy novel into a video game. A mind-bending tale with multiple endings.</td>
#       <td id="T_5102e_row0_col12" class="data row0 col12" >2018-12-28 00:00:00</td>
#       <td id="T_5102e_row0_col13" class="data row0 col13" >2018</td>
#       <td id="T_5102e_row0_col14" class="data row0 col14" >12</td>
#       <td id="T_5102e_row0_col15" class="data row0 col15" >312 min</td>
#       <td id="T_5102e_row0_col16" class="data row0 col16" >Contenido largo</td>
#     </tr>
#     <tr>
#       <th id="T_5102e_level0_row1" class="row_heading level0 row1" >717</th>
#       <td id="T_5102e_row1_col0" class="data row1 col0" >s718</td>
#       <td id="T_5102e_row1_col1" class="data row1 col1" >Movie</td>
#       <td id="T_5102e_row1_col2" class="data row1 col2" >Headspace: Unwind Your Mind</td>
#       <td id="T_5102e_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_5102e_row1_col4" class="data row1 col4" >Andy Puddicombe, Evelyn Lewis Prieto, Ginger Daniels, Darren Pettie, Simon Prebble, Rhiannon Mcgavin, Kate Seftel</td>
#       <td id="T_5102e_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_5102e_row1_col6" class="data row1 col6" >June 15, 2021</td>
#       <td id="T_5102e_row1_col7" class="data row1 col7" >2021</td>
#       <td id="T_5102e_row1_col8" class="data row1 col8" >TV-G</td>
#       <td id="T_5102e_row1_col9" class="data row1 col9" >273 min</td>
#       <td id="T_5102e_row1_col10" class="data row1 col10" >Documentaries</td>
#       <td id="T_5102e_row1_col11" class="data row1 col11" >Do you want to relax, meditate or sleep deeply? Personalize the experience according to your mood or mindset with this Headspace interactive special.</td>
#       <td id="T_5102e_row1_col12" class="data row1 col12" >2021-06-15 00:00:00</td>
#       <td id="T_5102e_row1_col13" class="data row1 col13" >2021</td>
#       <td id="T_5102e_row1_col14" class="data row1 col14" >6</td>
#       <td id="T_5102e_row1_col15" class="data row1 col15" >273 min</td>
#       <td id="T_5102e_row1_col16" class="data row1 col16" >Contenido largo</td>
#     </tr>
#     <tr>
#       <th id="T_5102e_level0_row2" class="row_heading level0 row2" >2491</th>
#       <td id="T_5102e_row2_col0" class="data row2 col0" >s2492</td>
#       <td id="T_5102e_row2_col1" class="data row2 col1" >Movie</td>
#       <td id="T_5102e_row2_col2" class="data row2 col2" >The School of Mischief</td>
#       <td id="T_5102e_row2_col3" class="data row2 col3" >Houssam El-Din Mustafa</td>
#       <td id="T_5102e_row2_col4" class="data row2 col4" >Suhair El-Babili, Adel Emam, Saeed Saleh, Younes Shalabi, Hadi El-Gayyar, Ahmad Zaki, Hassan Moustafa</td>
#       <td id="T_5102e_row2_col5" class="data row2 col5" >Egypt</td>
#       <td id="T_5102e_row2_col6" class="data row2 col6" >May 21, 2020</td>
#       <td id="T_5102e_row2_col7" class="data row2 col7" >1973</td>
#       <td id="T_5102e_row2_col8" class="data row2 col8" >TV-14</td>
#       <td id="T_5102e_row2_col9" class="data row2 col9" >253 min</td>
#       <td id="T_5102e_row2_col10" class="data row2 col10" >Comedies, Dramas, International Movies</td>
#       <td id="T_5102e_row2_col11" class="data row2 col11" >A high school teacher volunteers to transform five notorious misfits into model students — and has unintended results.</td>
#       <td id="T_5102e_row2_col12" class="data row2 col12" >2020-05-21 00:00:00</td>
#       <td id="T_5102e_row2_col13" class="data row2 col13" >2020</td>
#       <td id="T_5102e_row2_col14" class="data row2 col14" >5</td>
#       <td id="T_5102e_row2_col15" class="data row2 col15" >253 min</td>
#       <td id="T_5102e_row2_col16" class="data row2 col16" >Contenido largo</td>
#     </tr>
#     <tr>
#       <th id="T_5102e_level0_row3" class="row_heading level0 row3" >2487</th>
#       <td id="T_5102e_row3_col0" class="data row3 col0" >s2488</td>
#       <td id="T_5102e_row3_col1" class="data row3 col1" >Movie</td>
#       <td id="T_5102e_row3_col2" class="data row3 col2" >No Longer kids</td>
#       <td id="T_5102e_row3_col3" class="data row3 col3" >Samir Al Asfory</td>
#       <td id="T_5102e_row3_col4" class="data row3 col4" >Said Saleh, Hassan Moustafa, Ahmed Zaki, Younes Shalabi, Nadia Shukri, Karima Mokhtar</td>
#       <td id="T_5102e_row3_col5" class="data row3 col5" >Egypt</td>
#       <td id="T_5102e_row3_col6" class="data row3 col6" >May 21, 2020</td>
#       <td id="T_5102e_row3_col7" class="data row3 col7" >1979</td>
#       <td id="T_5102e_row3_col8" class="data row3 col8" >TV-14</td>
#       <td id="T_5102e_row3_col9" class="data row3 col9" >237 min</td>
#       <td id="T_5102e_row3_col10" class="data row3 col10" >Comedies, Dramas, International Movies</td>
#       <td id="T_5102e_row3_col11" class="data row3 col11" >Hoping to prevent their father from skipping town with his mistress, four rowdy siblings resort to absurd measures to stop him.</td>
#       <td id="T_5102e_row3_col12" class="data row3 col12" >2020-05-21 00:00:00</td>
#       <td id="T_5102e_row3_col13" class="data row3 col13" >2020</td>
#       <td id="T_5102e_row3_col14" class="data row3 col14" >5</td>
#       <td id="T_5102e_row3_col15" class="data row3 col15" >237 min</td>
#       <td id="T_5102e_row3_col16" class="data row3 col16" >Contenido largo</td>
#     </tr>
#     <tr>
#       <th id="T_5102e_level0_row4" class="row_heading level0 row4" >2484</th>
#       <td id="T_5102e_row4_col0" class="data ro

# %% [markdown]
# ### Pregunta Desafío
#
# 11. ¿Cuáles son las combinaciones más frecuentes de género y rating en el dataset?
#     (Sugerencia: utilizar `value_counts` con `subset=["genre", "rating"]` después de aplicar `explode()`).
#
#
#
# ### Bonus: Análisis de duplicados y limpieza
#
# 12. ¿Existen películas con el mismo nombre (`title`) pero con distinto año de lanzamiento (`release_year`)?
# 13. ¿Cuántos títulos únicos hay en total en la columna `title`?

# %%
df_exploded = df.assign(
    listed_in = df['listed_in'].str.split(r',\s*')
).explode('listed_in')
genre_rating_counts = df_exploded.value_counts(subset=['listed_in', 'rating']).head(10)
print(genre_rating_counts)
# Out:
# listed_in               rating
# International Movies    TV-MA     1130
#                         TV-14     1065
# Dramas                  TV-MA      830
# International TV Shows  TV-MA      714
# Dramas                  TV-14      693
# International TV Shows  TV-14      472
# Comedies                TV-14      465
# TV Dramas               TV-MA      434
# Comedies                TV-MA      431
# Dramas                  R          375
# Name: count, dtype: int64
